# %%
cookies = {
    "bggusername": "TYY_1121",
    "SessionID": "5199a1e4c7bfd5ee11a91f782523444e6391199du4182161"
}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://boardgamegeek.com/",
    "Accept-Encoding": "gzip, deflate, br"
}

# Get the above information from the browser's developer tools
# Cookies: Application -> Cookies
# Headers: Network -> Request Headers
# You may need to refresh the page to see the request in the developer tools

# %%
import requests
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import pandas as pd
import time
import random

def get_bgg_page(page_num, error_list):

    url = f"https://boardgamegeek.com/browse/boardgame/page/{page_num}"
    try:
        response = requests.get(url, headers=headers, cookies=cookies, timeout=10)
        response.raise_for_status()
        print("Getting page", page_num)
        # return response

        soup = BeautifulSoup(response.text, "html.parser")

        games = soup.select("tr[id^='row_']")  

        game_list = []
        for i, game in enumerate(games):

            rank = game.select_one(".collection_rank").text.strip()
            title_tag = game.select_one(".primary")
            title = title_tag.text.strip()
            game_id = int(title_tag["href"].split("/")[2])
            year = game.find("span", class_="smallerfont dull")
            year = year.text.strip() if year else None

            ratings = game.find_all("td", class_="collection_bggrating")
            geek_rating = ratings[0].text.strip()
            avg_rating = ratings[1].text.strip()
            
            link = "https://boardgamegeek.com" + title_tag["href"]

            game_list.append({
                "Rank": rank,
                "Name": title,
                "ID": game_id,
                "Year": year,
                "Geek Rating": geek_rating,
                "Avg Rating": avg_rating,
                "Link": link
            })

        for i in range(5):
            game_ids = ",".join([str(game["ID"]) for game in game_list[0+20*i:20+20*i]])
            get_game_info(game_ids, game_list, i)
            time.sleep(random.uniform(0.2, 0.8))


        # game_ids = ",".join([str(game["ID"]) for game in game_list])
        # get_game_info(game_ids, game_list)

        # time.sleep(random.uniform(1.2, 1.4))
            # return response

            
        
        return game_list
    
    except Exception as e:
        print(f"Page {page_num} Failed: {str(e)}")
        error_list.append(page_num)

# %%
def get_game_info(game_ids, gamelist, batch_id):
    api_url = f"https://api.geekdo.com/xmlapi2/thing?id={game_ids}&stats=1"
    response = requests.get(api_url, headers=headers, cookies=cookies)
    while response.status_code != 200:
        print(f"API ERROR at batch {batch_id}: {response.status_code}. Retrying...")

        time.sleep(random.uniform(3.3, 4.5))
        response = requests.get(api_url, headers=headers, cookies=cookies)

    xml_data = response.text

    if xml_data:
        # try:
        root = ET.fromstring(xml_data)
        for idx, game in enumerate(root.findall("item")):  # every <item>

            name = game.find("name").get("value")
            description = game.find("description").text

            min_players = game.find("minplayers").get("value")
            max_players = game.find("maxplayers").get("value")

            min_play_time = game.find("minplaytime").get("value")
            play_time = game.find("playingtime").get("value")

            weight = game.find("statistics/ratings/averageweight").get("value")


            categories = [link.get("value") for link in game.findall("link[@type='boardgamecategory']")]
            mechanics = [link.get("value") for link in game.findall("link[@type='boardgamemechanic']")]
            families = [link.get("value") for link in game.findall("link[@type='boardgamefamily']")]

            gamelist[batch_id*20+idx]["Min Players"] = min_players
            gamelist[batch_id*20+idx]["Max Players"] = max_players
            gamelist[batch_id*20+idx]["Min Play Time"] = min_play_time
            gamelist[batch_id*20+idx]["Play Time"] = play_time
            gamelist[batch_id*20+idx]["Weight"] = weight
            gamelist[batch_id*20+idx]["Description"] = description
            gamelist[batch_id*20+idx]["Categories"] = categories
            gamelist[batch_id*20+idx]["Mechanics"] = mechanics
            gamelist[batch_id*20+idx]["Families"] = families
        
        # except Exception as e:
        #     print(f"XML ERROR:", str(e))
        #     return None


        # print(f"Name: {name}")
        # print(f"Description: {description[:200]}...")
        # print(f"Categories: {', '.join(categories)}")
        # print(f"Players: {min_players} - {max_players}")
        # print(f"Time: {play_time} 分钟")
        # print(f"Complexity: {weight} / 5")
        # print(f"Mechanics: {', '.join(mechanics)}")
        # print(f"Families: {', '.join(families)}")

# %%
import json

error_list = []
for i in range(1200, 1400):
    start_time = time.time()

    game_list = get_bgg_page(i, error_list)

    with open(f"data/bgg_data_{i}.json", "w") as f:
        json.dump(game_list, f, indent=2)

    print("Saving page", i, "at time", time.time() - start_time)
# Out:
# Getting page 1200
# Saving page 1200 at time 4.3947179317474365
# Getting page 1201
# Saving page 1201 at time 4.181240081787109
# Getting page 1202
# Saving page 1202 at time 4.3896849155426025
# Getting page 1203
# Saving page 1203 at time 4.644099712371826
# Getting page 1204
# Saving page 1204 at time 4.639185190200806
# Getting page 1205
# Saving page 1205 at time 4.888067960739136
# Getting page 1206
# Saving page 1206 at time 5.070065975189209
# Getting page 1207
# Saving page 1207 at time 6.259059190750122
# Getting page 1208
# Saving page 1208 at time 5.015361785888672
# Getting page 1209
# API ERROR at batch 2: 429. Retrying...
# Saving page 1209 at time 9.44755482673645
# Getting page 1210
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1210 at time 12.88734221458435
# Getting page 1211
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1211 at time 13.998465061187744
# Getting page 1212
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1212 at time 12.931441068649292
# Getting page 1213
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1213 at time 12.470980167388916
# Getting page 1214
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1214 at time 13.215783834457397
# Getting page 1215
# API ERROR at batch 4: 429. Retrying...
# Saving page 1215 at time 10.090725898742676
# Getting page 1216
# API ERROR at batch 2: 429. Retrying...
# Saving page 1216 at time 8.987834930419922
# Getting page 1217
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1217 at time 16.099683046340942
# Getting page 1218
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1218 at time 12.935186862945557
# Getting page 1219
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1219 at time 13.078099250793457
# Getting page 1220
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1220 at time 12.144777059555054
# Getting page 1221
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1221 at time 13.488648176193237
# Getting page 1222
# API ERROR at batch 3: 429. Retrying...
# Saving page 1222 at time 8.966514110565186
# Getting page 1223
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1223 at time 13.764191150665283
# Getting page 1224
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1224 at time 12.84688687324524
# Getting page 1225
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1225 at time 13.615470170974731
# Getting page 1226
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1226 at time 14.11617922782898
# Getting page 1227
# API ERROR at batch 2: 429. Retrying...
# Saving page 1227 at time 9.942912101745605
# Getting page 1228
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1228 at time 16.464127779006958
# Getting page 1229
# API ERROR at batch 2: 429. Retrying...
# Saving page 1229 at time 9.628146886825562
# Getting page 1230
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1357 at time 12.75513219833374
# Getting page 1358
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1358 at time 14.094138145446777
# Getting page 1359
# API ERROR at batch 2: 429. Retrying...
# Saving page 1359 at time 9.567134380340576
# Getting page 1360
# API ERROR at batch 3: 429. Retrying...
# Saving page 1360 at time 10.438991785049438
# Getting page 1361
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1361 at time 13.201665878295898
# Getting page 1362
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1362 at time 13.510692834854126
# Getting page 1363
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1363 at time 12.56349492073059
# Getting page 1364
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1364 at time 12.494977712631226
# Getting page 1365
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1365 at time 14.325788259506226
# Getting page 1366
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1366 at time 12.58255410194397
# Getting page 1367
# API ERROR at batch 3: 429. Retrying...
# Saving page 1367 at time 10.27887225151062
# Getting page 1368
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1368 at time 13.835639715194702
# Getting page 1369
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1369 at time 12.303812026977539
# Getting page 1370
# API ERROR at batch 2: 429. Retrying...
# Saving page 1370 at time 11.419881820678711
# Getting page 1371
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1371 at time 12.989418029785156
# Getting page 1372
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1372 at time 11.827505826950073
# Getting page 1373
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1373 at time 13.963554859161377
# Getting page 1374
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1374 at time 13.046482801437378
# Getting page 1375
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1375 at time 16.826638221740723
# Getting page 1376
# API ERROR at batch 3: 429. Retrying...
# Saving page 1376 at time 9.485652208328247
# Getting page 1377
# API ERROR at batch 3: 429. Retrying...
# Saving page 1377 at time 10.051883220672607
# Getting page 1378
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1378 at time 12.028042793273926
# Getting page 1379
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1379 at time 13.411938905715942
# Getting page 1380
# API ERROR at batch 3: 429. Retrying...
# Saving page 1380 at time 9.848795890808105
# Getting page 1381
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1381 at time 13.930606126785278
# Getting page 1382
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1382 at time 13.87075686454773
# Getting page 1383
# API ERROR at batch 3: 429. Retrying...
# Saving page 1383 at time 11.085745811462402
# Getting page 1384
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1384 at time 13.477296113967896
# Getting page 1385
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1385 at time 13.140920162200928
# Getting page 1386
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1386 at time 14.019264936447144
# Getting page 1387
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1387 at time 12.424493789672852
# Getting page 1388
# API ERROR at batch 1: 429. Retrying...
# Saving page 1388 at time 8.731274843215942
# Getting page 1389
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1389 at time 13.968618869781494
# Getting page 1390
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1390 at time 12.845908880233765
# Getting page 1391
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1391 at time 13.394753217697144
# Getting page 1392
# API ERROR at batch 1: 429. Retrying...
# Saving page 1392 at time 8.450484991073608
# Getting page 1393
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1393 at time 16.015286922454834
# Getting page 1394
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1394 at time 11.049906969070435
# Getting page 1395
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1395 at time 12.379684209823608
# Getting page 1396
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1396 at time 13.272954225540161
# Getting page 1397
# API ERROR at batch 1: 429. Retrying...
# API ERROR at batch 3: 429. Retrying...
# Saving page 1397 at time 11.504857063293457
# Getting page 1398
# API ERROR at batch 0: 429. Retrying...
# API ERROR at batch 2: 429. Retrying...
# API ERROR at batch 4: 429. Retrying...
# Saving page 1398 at time 16.624181985855103
# Getting page 1399
# API ERROR at batch 3: 429. Retrying...
# Saving page 1399 at time 8.726807117462158

# %%
error_list
# Out:
# [1314, 1343]

# %%
import json

for i in error_list:
    start_time = time.time()

    game_list = get_bgg_page(i, error_list)

    with open(f"data/bgg_data_{i}.json", "w") as f:
        json.dump(game_list, f, indent=2)

    print("Saving page", i, "at time", time.time() - start_time)
# Out:
# Getting page 1314
# Saving page 1314 at time 4.30379319190979
# Getting page 1343
# Saving page 1343 at time 4.154666185379028
